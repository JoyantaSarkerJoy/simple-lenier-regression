# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a14aa3cb-2802-428f-ada1-730e06115667" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a14aa3cb-2802-428f-ada1-730e06115667">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FuelConsumption.csv to FuelConsumption.csv
# User uploaded file "FuelConsumption.csv" with length 72629 bytes

# %%
df=pd.read_csv("FuelConsumption.csv")

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= df[['ENGINESIZE']].values
y= df['CO2EMISSIONS']

# %%
plt.scatter(x,y,marker='*',color='blue')
plt.xlabel("Engine Size")
plt.ylabel("CO2 Emission")
plt.title("Emission Prediction")
# Out:
# Text(0.5, 1.0, 'Emission Prediction')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20, random_state=1)

# %%
x_train
# Out:
# array([[3. ],
#        [6.4],
#        [2.5],
#        [4.8],
#        [4. ],
#        [1.5],
#        [1.6],
#        [2. ],
#        [3.2],
#        [3.6],
#        [6.2],
#        [3. ],
#        [4.4],
#        [2. ],
#        [3.5],
#        [3.5],
#        [3.5],
#        [1.6],
#        [1.4],
#        [5.7],
#        [5. ],
#        [2. ],
#        [1.4],
#        [3.6],
#        [5. ],
#        [5.6],
#        [4.8],
#        [2.5],
#        [2. ],
#        [6.2],
#        [5. ],
#        [3. ],
#        [1.6],
#        [3.4],
#        [2.4],
#        [3.7],
#        [5. ],
#        [3.7],
#        [3.5],
#        [5.7],
#        [1.6],
#        [3.2],
#        [5.2],
#        [4. ],
#        [5. ],
#        [3.6],
#        [3.5],
#        [3. ],
#        [4.3],
#        [5.6],
#        [1.8],
#        [3.5],
#        [2. ],
#        [5.5],
#        [4.6],
#        [2. ],
#        [2. ],
#        [3.2],
#        [1.5],
#        [1.6],
#        [3.5],
#        [4.6],
#        [1.8],
#        [5.3],
#        [2. ],
#        [2. ],
#        [2.5],
#        [5.5],
#        [1.5],
#        [4. ],
#        [4.4],
#        [3. ],
#        [2. ],
#        [3.6],
#        [2. ],
#        [5.9],
#        [1.8],
#        [2.5],
#        [5.3],
#        [3.5],
#        [6.8],
#        [5.5],
#        [2.7],
#        [2.5],
#        [2. ],
#        [3.5],
#        [2.4],
#        [2.7],
#        [5. ],
#        [5.7],
#        [3.6],
#        [4.4],
#        [1.6],
#        [3.6],
#        [2.5],
#        [4.7],
#        [6.7],
#        [3.7],
#        [3.5],
#        [3.6],
#        [2. ],
#        [2.7],
#        [5.6],
#        [4.4],
#        [6.6],
#        [2. ],
#        [3.6],
#        [6. ],
#        [2. ],
#        [2.5],
#        [2.4],
#        [6.2],
#        [2. ],
#        [2.4],
#        [2. ],
#        [1.6],
#        [2.5],
#        [6. ],
#        [5.3],
#        [2. ],
#        [5.3],
#        [3. ],
#        [4.4],
#        [4.3],
#        [2.4],
#        [1.8],
#        [1.4],
#        [2.5],
#        [4.6],
#        [3.6],
#        [3.6],
#        [2. ],
#        [2.5],
#        [5.4],
#        [1.5],
#        [4. ],
#        [2.5],
#        [5. ],
#        [3. ],
#        [2. ],
#        [1.6],
#        [3.6],
#        [2. ],
#        [1.8],
#        [3.6],
#        [1. ],
#        [4.4],
#        [3. ],
#        [1.5],
#        [2.7],
#        [2. ],
#        [3. ],
#        [2.5],
#        [4.3],
#        [5.3],
#        [3.7],
#        [3.7],
#        [3.3],
#        [2.7],
#        [2. ],
#        [3.6],
#        [5.2],
#        [3.6],
#        [2.4],
#        [3.6],
#        [6. ],
#        [5. ],
#        [2.5],
#        [2.4],
#        [3.5],
#        [2.5],
#        [3.5],
#        [2. ],
#        [2.4],
#        [3.5],
#        [5.7],
#        [2. ],
#        [2.4],
#        [5. ],
#        [3.7],
#        [3.6],
#        [2. ],
#        [1.6],
#        [2.4],
#        [2. ],
#        [1.2],
#        [5.3],
#        [1.4],
#        [3.6],
#        [1.6],
#        [3.5],
#        [2.4],
#        [2. ],
#        [2. ],
#        [2. ],
#        [1.6],
#        [1.4],
#        [3.6],
#        [5.3],
#        [5.3],
#        [3.6],
#        [2. ],
#        [2.7],
#        [3. ],
#        [2.7],
#        [2.4],
#        [1.8],
#        [2. ],
#        [6.2],
#        [3.7],
#        [5.3],
#        [5. ],
#        [4.4],
#        [3.5],
#        [2.4],
#        [3. ],
#        [3.6],
#        [6.2],
#        [3.6],
#        [3.5],
#        [2. ],
#        [3. ],
#        [6.2],
#        [1.6],
#        [4. ],
#        [2. ],
#        [5.3],
#        [3.6],
#        [5.3],
#        [3. ],
#        [2.4],
#        [3.6],
#        [4.4],
#        [2.5],
#        [2. ],
#        [3.4],
#        [5.4],
#        [1.6],
#        [2. ],
#        [2. ],
#        [3.6],
#        [3.7],
#        [1.6],
#        [3. ],
#        [4.7],
#        [4.7],
#        [5.3],
#        [3.7],
#        [2. ],
#        [5. ],
#        [4.7],
#        [1.8],
#        [3.4],
#        [3. ],
#        [2. ],
#        [1.4],
#        [5. ],
#        [3.6],
#        [2. ],
#        [2.4],
#        [4.4],
#        [3.7],
#        [1.6],
#        [3.5],
#        [4.8],
#        [6.2],
#        [4.2],
#        [3.5],
#        [2.4],
#        [1.6],
#        [1.6],
#        [1.6],
#        [6. ],
#        [1.6],
#        [3.5],
#        [5.3],
#        [4.6],
#        [4. ],
#        [1.6],
#        [3.6],
#        [5.7],
#        [5.7],
#        [2.4],
#        [2.5],
#        [3. ],
#        [3.8],
#        [3.8],
#        [3.5],
#        [5.3],
#        [1.6],
#        [6.2],
#        [2. ],
#        [2.4],
#        [3.5],
#        [4.8],
#        [3.6],
#        [4. ],
#        [2.4],
#        [2.5],
#        [4. ],
#        [5.7],
#        [5.3],
#        [2.5],
#        [2. ],
#        [3.5],
#        [4.4],
#        [3. ],
#        [5.4],
#        [3. ],
#        [6.2],
#        [5.3],
#        [1.5],
#        [6.2],
#        [3. ],
#        [3.6],
#        [3.6],
#        [4.7],
#        [6. ],
#        [1.6],
#        [2. ],
#        [5.4],
#        [3. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [2. ],
#        [6.7],
#        [1. ],
#        [4.2],
#        [1.6],
#        [1.6],
#        [5. ],
#        [2. ],
#        [3.7],
#        [6. ],
#        [3.6],
#        [6. ],
#        [3.5],
#        [2.4],
#        [4.7],
#        [3. ],
#        [3.8],
#        [2.5],
#        [2.4],
#        [1.4],
#        [6.7],
#        [3.7],
#        [2. ],
#        [1.4],
#        [3.8],
#        [1.6],
#        [3.6],
#        [3.8],
#        [3.5],
#        [1.8],
#        [2.4],
#        [4.4],
#        [3.7],
#        [2. ],
#        [2. ],
#        [3.2],
#        [3.6],
#        [2. ],
#        [4.4],
#        [3. ],
#        [3.5],
#        [3.5],
#        [3. ],
#        [4.7],
#        [2.5],
#        [3.5],
#        [3.5],
#        [3.7],
#        [5. ],
#        [3.5],
#        [3.5],
#        [3.8],
#        [2. ],
#        [1.3],
#        [3.5],
#        [1.2],
#        [1.4],
#        [2. ],
#        [1.6],
#        [3.5],
#        [3.5],
#        [2. ],
#        [3.6],
#        [3.6],
#        [3. ],
#        [2.5],
#        [1.6],
#        [3.4],
#        [8.4],
#        [1.6],
#        [2.5],
#        [5.7],
#        [4. ],
#        [2.5],
#        [5.5],
#        [3. ],
#        [5.3],
#        [1.4],
#        [1.8],
#        [2.4],
#        [3.7],
#        [3.5],
#        [2.4],
#        [1.8],
#        [4.8],
#        [4.7],
#        [3. ],
#        [2. ],
#        [3.3],
#        [3.7],
#        [5. ],
#        [1.4],
#        [4.6],
#        [1.6],
#        [3. ],
#        [2. ],
#        [1.6],
#        [1.8],
#        [4.3],
#        [5. ],
#        [2. ],
#        [3.2],
#        [2.4],
#        [5.3],
#        [2. ],
#        [1.8],
#        [2.5],
#        [2. ],
#        [3.5],
#        [5.3],
#        [2. ],
#        [3. ],
#        [2.4],
#        [1.8],
#        [6. ],
#        [5.9],
#        [3.6],
#        [3.6],
#        [4.6],
#        [3.5],
#        [6.6],
#        [3.7],
#        [2.4],
#        [1.8],
#        [3.6],
#        [5.5],
#        [2. ],
#        [5.3],
#        [1.4],
#        [3.5],
#        [3.6],
#        [2. ],
#        [3. ],
#        [2.5],
#        [3. ],
#        [6. ],
#        [3. ],
#        [3. ],
#        [5.4],
#        [3.5],
#        [5.3],
#        [5. ],
#        [5.4],
#        [1.8],
#        [1.8],
#        [2. ],
#        [5.2],
#        [3.8],
#        [2. ],
#        [2.5],
#        [2. ],
#        [1.8],
#        [3.4],
#        [3.6],
#        [2. ],
#        [5.5],
#        [3.6],
#        [5. ],
#        [4. ],
#        [3. ],
#        [1.6],
#        [6.2],
#        [2. ],
#        [2. ],
#        [2.5],
#        [1.6],
#        [3. ],
#        [2.4],
#        [2.4],
#        [4. ],
#        [3.5],
#        [1.8],
#        [3.6],
#        [3. ],
#        [3.8],
#        [1.6],
#        [3. ],
#        [3.7],
#        [3.8],
#        [4.7],
#        [2. ],
#        [5.3],
#        [1.8],
#        [3. ],
#        [3.5],
#        [2.4],
#        [3.7],
#        [1.6],
#        [4. ],
#        [5.3],
#        [2. ],
#        [2. ],
#        [2. ],
#        [5. ],
#        [2. ],
#        [4.8],
#        [3.5],
#        [1.5],
#        [1.4],
#        [6. ],
#        [3.7],
#        [2.5],
#        [2.4],
#        [3. ],
#        [3.6],
#        [5.3],
#        [4.4],
#        [5. ],
#        [6.2],
#        [3.7],
#        [2. ],
#        [3.6],
#        [2. ],
#        [1.6],
#        [4.4],
#        [3. ],
#        [5.2],
#        [2. ],
#        [3.3],
#        [2.4],
#        [1.6],
#        [2. ],
#        [1.4],
#        [6.2],
#        [1.6],
#        [6.4],
#        [4.7],
#        [3. ],
#        [5.3],
#        [3.6],
#        [2.5],
#        [3.6],
#        [2.7],
#        [4.3],
#        [3.7],
#        [2.5],
#        [3.5],
#        [3.6],
#        [3.6],
#        [3.6],
#        [3.6],
#        [3.6],
#        [3.5],
#        [3.6],
#        [3.6],
#        [3.5],
#        [2. ],
#        [2. ],
#        [1.8],
#        [3.6],
#        [2. ],
#        [8.4],
#        [2.7],
#        [2.4],
#        [2. ],
#        [4. ],
#        [5.4],
#        [4.6],
#        [1. ],
#        [2.5],
#        [1.8],
#        [2.5],
#        [5.6],
#        [1.6],
#        [3.5],
#        [3. ],
#        [6.4],
#        [5.5],
#        [5.3],
#        [2. ],
#        [4.2],
#        [2.1],
#        [6.2],
#        [3. ],
#        [3.2],
#        [3.5],
#        [1.4],
#        [1.6],
#        [3.5],
#        [6.2],
#        [4.6],
#        [1.4],
#        [4.2],
#        [1.6],
#        [3. ],
#        [2. ],
#        [5.3],
#        [3.5],
#        [3. ],
#        [2.4],
#        [2. ],
#        [3.6],
#        [2. ],
#        [3. ],
#        [2. ],
#        [3. ],
#        [2. ],
#        [3.6],
#        [5.3],
#        [3. ],
#        [3.6],
#        [1.8],
#        [3. ],
#        [2. ],
#        [1.8],
#        [4. ],
#        [2. ],
#        [4.2],
#        [5.7],
#        [3.6],
#        [5. ],
#        [5. ],
#        [5.3],
#        [3. ],
#        [4. ],
#        [3. ],
#        [1.5],
#        [3.7],
#        [1.8],
#        [1.4],
#        [6. ],
#        [2.5],
#        [2.5],
#        [2.5],
#        [2.5],
#        [5. ],
#        [6.2],
#        [3.5],
#        [1.8],
#        [3.6],
#        [3.5],
#        [3. ],
#        [5.3],
#        [2.5],
#        [3.6],
#        [2. ],
#        [2.1],
#        [3.4],
#        [5.8],
#        [3.6],
#        [2. ],
#        [1.8],
#        [4.8],
#        [3. ],
#        [5.6],
#        [2.5],
#        [2.5],
#        [5. ],
#        [1.6],
#        [2. ],
#        [5.3],
#        [2.5],
#        [2. ],
#        [2. ],
#        [2. ],
#        [3.6],
#        [3.6],
#        [2. ],
#        [3.5],
#        [5. ],
#        [2. ],
#        [3.6],
#        [2.5],
#        [2. ],
#        [3.5],
#        [3. ],
#        [1.6],
#        [1.6],
#        [3.5],
#        [3.6],
#        [2.4],
#        [2. ],
#        [3.6],
#        [2. ],
#        [3.6],
#        [2. ],
#        [5. ],
#        [6.2],
#        [3.6],
#        [2.5],
#        [1.4],
#        [5.3],
#        [2. ],
#        [1.8],
#        [4. ],
#        [2. ],
#        [5.3],
#        [3.4],
#        [1.6],
#        [4.7],
#        [2.4],
#        [3. ],
#        [3.4],
#        [2. ],
#        [1.4],
#        [2.5],
#        [1.8],
#        [3.2],
#        [1.6],
#        [6.2],
#        [3.6],
#        [3.7],
#        [3.5],
#        [6.2],
#        [2.5],
#        [2.4],
#        [3.4],
#        [1.8],
#        [3.5],
#        [3. ],
#        [1.5],
#        [2.4],
#        [3.6],
#        [3. ],
#        [4.3],
#        [2.5],
#        [5.5],
#        [2.4],
#        [1.6],
#        [3.5],
#        [3.8],
#        [3. ],
#        [2. ],
#        [3.7],
#        [3. ],
#        [1.4],
#        [6.8],
#        [2. ],
#        [2. ],
#        [5.3],
#        [3.2],
#        [2. ],
#        [6.4],
#        [2.4],
#        [4.3],
#        [5.3],
#        [5. ],
#        [1.8],
#        [5.3],
#        [1.8],
#        [4.8],
#        [5.5],
#        [1.6],
#        [3.5],
#        [1.4],
#        [2. ],
#        [2. ],
#        [2. ],
#        [6.6],
#        [3.6],
#        [3.6],
#        [3.6],
#        [4.6],
#        [4.3],
#        [3.5],
#        [1.6],
#        [3. ],
#        [5.5],
#        [1.8],
#        [3.5],
#        [6.2],
#        [5. ],
#        [3.6],
#        [5. ],
#        [2. ],
#        [2.4],
#        [6.4],
#        [2.5],
#        [2.4],
#        [1.6],
#        [5. ],
#        [2.4],
#        [2. ],
#        [2.7],
#        [2. ],
#        [6.2],
#        [2. ],
#        [1.6],
#        [3.5],
#        [3.6],
#        [3. ],
#        [5.3],
#        [5.5],
#        [3.5],
#        [2. ],
#        [6.2],
#        [4.7],
#        [3.8],
#        [2.4],
#        [1.5],
#        [1.6],
#        [2. ],
#        [2.4],
#        [3.5],
#        [5.3],
#        [6.5],
#        [2.5],
#        [2. ],
#        [3.5],
#        [3.6],
#        [2.4],
#        [2. ],
#        [2. ],
#        [2.4],
#        [2.5],
#        [3.6],
#        [5.5],
#        [4. ],
#        [2.4],
#        [5. ],
#        [3.5],
#        [5. ],
#        [1.4],
#        [4.8],
#        [3.6],
#        [3.6],
#        [2. ],
#        [3.3],
#        [4.7],
#        [3. ],
#        [3.6],
#        [3.6],
#        [1.6],
#        [2.5],
#        [4.8],
#        [2.4],
#        [3.2]])

# %%
from sklearn.linear_model import LinearRegression
joy=LinearRegression()
joy.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
joy.predict(x_test)
# Out:
# array([243.01671902, 179.95211967, 203.60134443, 203.60134443,
#        306.08131838, 243.01671902, 203.60134443, 195.71826951,
#        243.01671902, 219.36749427, 219.36749427, 243.01671902,
#        219.36749427, 329.73054314, 223.30903173, 223.30903173,
#        187.83519459, 298.19824346, 262.72440632, 219.36749427,
#        361.26284282, 223.30903173, 270.60748124, 262.72440632,
#        270.60748124, 243.01671902, 172.06904475, 341.55515552,
#        187.83519459, 203.60134443, 243.01671902, 329.73054314,
#        262.72440632, 333.6720806 , 282.43209362, 333.6720806 ,
#        369.14591774, 183.89365713, 290.31516854, 254.8413314 ,
#        243.01671902, 373.0874552 , 203.60134443, 266.66594378,
#        270.60748124, 203.60134443, 179.95211967, 179.95211967,
#        203.60134443, 258.78286886, 187.83519459, 349.43823044,
#        294.256706  , 369.14591774, 203.60134443, 270.60748124,
#        223.30903173, 321.84746822, 270.60748124, 187.83519459,
#        219.36749427, 231.19210664, 203.60134443, 203.60134443,
#        203.60134443, 195.71826951, 270.60748124, 266.66594378,
#        203.60134443, 187.83519459, 203.60134443, 203.60134443,
#        266.66594378, 262.72440632, 321.84746822, 369.14591774,
#        203.60134443, 369.14591774, 203.60134443, 270.60748124,
#        369.14591774, 179.95211967, 349.43823044, 321.84746822,
#        203.60134443, 369.14591774, 274.5490187 , 262.72440632,
#        203.60134443, 266.66594378, 333.6720806 , 298.19824346,
#        203.60134443, 262.72440632, 203.60134443, 203.60134443,
#        333.6720806 , 388.85360504, 203.60134443, 282.43209362,
#        219.36749427, 369.14591774, 203.60134443, 262.72440632,
#        187.83519459, 298.19824346, 195.71826951, 333.6720806 ,
#        195.71826951, 203.60134443, 219.36749427, 369.14591774,
#        341.55515552, 298.19824346, 333.6720806 , 262.72440632,
#        223.30903173, 223.30903173, 321.84746822, 203.60134443,
#        274.5490187 , 294.256706  , 203.60134443, 270.60748124,
#        203.60134443, 203.60134443, 349.43823044, 349.43823044,
#        310.02285584, 203.60134443, 219.36749427, 187.83519459,
#        266.66594378, 266.66594378, 333.6720806 , 310.02285584,
#        321.84746822, 187.83519459, 333.6720806 , 219.36749427,
#        179.95211967, 203.60134443, 203.60134443, 172.06904475,
#        310.02285584, 203.60134443, 321.84746822, 337.61361806,
#        333.6720806 , 266.66594378, 203.60134443, 243.01671902,
#        357.32130536, 345.49669298, 262.72440632, 223.30903173,
#        262.72440632, 369.14591774, 195.71826951, 203.60134443,
#        187.83519459, 266.66594378, 282.43209362, 179.95211967,
#        243.01671902, 349.43823044, 203.60134443, 262.72440632,
#        349.43823044, 262.72440632, 270.60748124, 310.02285584,
#        282.43209362, 187.83519459, 321.84746822, 243.01671902,
#        369.14591774, 258.78286886, 183.89365713, 361.26284282,
#        282.43209362, 333.6720806 , 243.01671902, 179.95211967,
#        262.72440632, 262.72440632, 219.36749427, 262.72440632,
#        262.72440632, 179.95211967, 203.60134443, 187.83519459,
#        219.36749427, 361.26284282, 298.19824346, 266.66594378,
#        262.72440632, 258.78286886, 349.43823044, 298.19824346,
#        262.72440632, 274.5490187 , 262.72440632, 266.66594378,
#        266.66594378, 203.60134443, 187.83519459, 274.5490187 ,
#        219.36749427, 266.66594378, 187.83519459, 274.5490187 ,
#        270.60748124, 203.60134443])

# %%
joy.predict([[100]])
# Out:
# array([4066.30805499])

# %%
joy.score(x_test,y_test)
# Out:
# 0.7644809223805962

# %%
print(joy.intercept_)w0
# Out:
# 124.77059523158408

# %%
print(joy.coef_)W
# Out:
# [39.4153746]

# %%
print(39.42*31-124.77)
# Out:
# 1097.25
